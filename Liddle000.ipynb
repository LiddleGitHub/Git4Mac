# %% [markdown]
# <a href="https://colab.research.google.com/github/LiddleGitHub/Git4Mac/blob/master/Liddle000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hullo")
# Out:
# hullo

# %% [markdown]
# Don't forget to menu - save
#
# 2026.01.18

# %%
print ("more cells here")
# Out:
# more cells here
